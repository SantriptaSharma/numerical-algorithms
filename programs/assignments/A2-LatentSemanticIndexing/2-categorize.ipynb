# %%
import json

# %load_ext autoreload
# %autoreload 2

books_obj = {}
with open("books_cleaned.json", "r") as f:
	books_obj = json.load(f)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Here, we find all the DDN classes we have, and all the books (their titles, actually) belonging to them.
#
# One subtlety is that a book with the DDN 317 belongs to all of the classes 300, 310, and 317.
#
# We only consider the top level 3 decimal digits, so 317.134 only belongs to 300, 310, and 317

# %%
from helpers import extract_categories

extract_categories("315.3814", 0, 1)
# Out:
# ['315']

# %%
cat_to_ids = {}

for id, book in books_obj.items():
	cats = extract_categories(book["ddn"], 0, 1)

	for cat in cats:
		if cat not in cat_to_ids:
			cat_to_ids[cat] = [id]
		else:
			cat_to_ids[cat].append(id)

# %%
all_cats = sorted(list(cat_to_ids.keys()))

print(len(all_cats))
# Out:
# 521

# %%
CAT_IDS_THRESH = 1

filtered_cat_to_ids = {cat: ids for cat, ids in cat_to_ids.items() if len(ids) >= CAT_IDS_THRESH}
len(filtered_cat_to_ids)
# Out:
# 521

# %%
cat_counts = sorted([(cat, len(ids)) for cat, ids in filtered_cat_to_ids.items()], key=lambda t:t[1], reverse=True)
cat_counts
# Out:
# [('954', 514),
#  ('823', 454),
#  ('320', 273),
#  ('294', 252),
#  ('327', 236),
#  ('813', 222),
#  ('338', 218),
#  ('305', 213),
#  ('306', 181),
#  ('330', 176),
#  ('891', 169),
#  ('951', 158),
#  ('301', 157),
#  ('658', 106),
#  ('335', 102),
#  ('333', 102),
#  ('355', 97),
#  ('303', 94),
#  ('181', 86),
#  ('940', 82),
#  ('915', 77),
#  ('512', 76),
#  ('909', 73),
#  ('515', 72),
#  ('808', 62),
#  ('332', 56),
#  ('959', 56),
#  ('820', 55),
#  ('363', 55),
#  ('809', 53),
#  ('304', 53),
#  ('193', 52),
#  ('791', 52),
#  ('616', 49),
#  ('302', 48),
#  ('895', 48),
#  ('821', 46),
#  ('297', 45),
#  ('822', 45),
#  ('759', 44),
#  ('519', 43),
#  ('973', 43),
#  ('342', 42),
#  ('709', 42),
#  ('321', 41),
#  ('150', 41),
#  ('510', 40),
#  ('307', 39),
#  ('331', 39),
#  ('382', 38),
#  ('323', 36),
#  ('491', 36),
#  ('341', 34),
#  ('530', 34),
#  ('324', 33),
#  ('121', 33),
#  ('325', 32),
#  ('934', 32),
#  ('901', 32),
#  ('300', 31),
#  ('501', 31),
#  ('322', 31),
#  ('947', 30),
#  ('005', 29),
#  ('170', 29),
#  ('894', 29),
#  ('950', 28),
#  ('370', 28),
#  ('572', 28),
#  ('923', 27),
#  ('155', 26),
#  ('828', 26),
#  ('194', 25),
#  ('337', 25),
#  ('509', 25),
#  ('956', 25),
#  ('192', 24),
#  ('362', 24),
#  ('364', 23),
#  ('843', 23),
#  ('153', 23),
#  ('941', 23),
#  ('599', 23),
#  ('801', 22),
#  ('111', 22),
#  ('128', 22),
#  ('944', 22),
#  ('910', 22),
#  ('516', 21),
#  ('158', 21),
#  ('001', 20),
#  ('378', 20),
#  ('839', 20),
#  ('920', 20),
#  ('833', 20),
#  ('340', 19),
#  ('615', 19),
#  ('398', 19),
#  ('612', 18),
#  ('511', 18),
#  ('576', 18),
#  ('700', 18),
#  ('309', 18),
#  ('339', 17),
#  ('004', 17),
#  ('958', 17),
#  ('914', 17),
#  ('149', 16),
#  ('371', 16),
#  ('336', 16),
#  ('291', 16),
#  ('930', 16),
#  ('152', 16),
#  ('200', 16),
#  ('577', 16),
#  ('508', 16),
#  ('191', 15),
#  ('907', 15),
#  ('190', 15),
#  ('792', 15),
#  ('401', 15),
#  ('131', 15),
#  ('354', 15),
#  ('780', 14),
#  ('863', 14),
#  ('613', 14),
#  ('172', 14),
#  ('869', 14),
#  ('523', 14),
#  ('100', 13),
#  ('070', 13),
#  ('972', 13),
#  ('943', 13),
#  ('361', 12),
#  ('621', 12),
#  ('171', 12),
#  ('704', 12),
#  ('811', 12),
#  ('184', 11),
#  ('514', 11),
#  ('610', 11),
#  ('701', 11),
#  ('741', 11),
#  ('942', 11),
#  ('598', 11),
#  ('110', 11),
#  ('329', 11),
#  ('853', 11),
#  ('160', 10),
#  ('261', 10),
#  ('848', 10),
#  ('720', 10),
#  ('352', 10),
#  ('726', 10),
#  ('952', 10),
#  ('570', 10),
#  ('818', 9),
#  ('142', 9),
#  ('174', 9),
#  ('346', 9),
#  ('551', 9),
#  ('410', 9),
#  ('824', 9),
#  ('938', 9),
#  ('591', 9),
#  ('050', 9),
#  ('006', 8),
#  ('328', 8),
#  ('913', 8),
#  ('347', 8),
#  ('344', 8),
#  ('345', 8),
#  ('892', 8),
#  ('614', 8),
#  ('133', 8),
#  ('365', 8),
#  ('810', 8),
#  ('418', 8),
#  ('636', 8),
#  ('571', 8),
#  ('394', 7),
#  ('180', 7),
#  ('144', 7),
#  ('384', 7),
#  ('937', 7),
#  ('631', 7),
#  ('650', 7),
#  ('796', 7),
#  ('358', 7),
#  ('574', 7),
#  ('980', 7),
#  ('595', 7),
#  ('641', 7),
#  ('290', 7),
#  ('016', 7),
#  ('126', 7),
#  ('928', 7),
#  ('211', 6),
#  ('230', 6),
#  ('517', 6),
#  ('832', 6),
#  ('750', 6),
#  ('953', 6),
#  ('659', 6),
#  ('955', 6),
#  ('201', 6),
#  ('392', 6),
#  ('069', 6),
#  ('500', 6),
#  ('746', 6),
#  ('428', 6),
#  ('535', 6),
#  ('210', 5),
#  ('179', 5),
#  ('531', 5),
#  ('793', 5),
#  ('781', 5),
#  ('962', 5),
#  ('968', 5),
#  ('539', 5),
#  ('351', 5),
#  ('372', 5),
#  ('379', 5),
#  ('359', 5),
#  ('003', 5),
#  ('248', 5),
#  ('778', 5),
#  ('996', 5),
#  ('960', 5),
#  ('526', 5),
#  ('275', 5),
#  ('916', 5),
#  ('730', 5),
#  ('141', 5),
#  ('931', 5),
#  ('882', 5),
#  ('520', 5),
#  ('782', 5),
#  ('423', 5),
#  ('851', 4),
#  ('518', 4),
#  ('189', 4),
#  ('770', 4),
#  ('751', 4),
#  ('381', 4),
#  ('844', 4),
#  ('657', 4),
#  ('745', 4),
#  ('082', 4),
#  ('814', 4),
#  ('390', 4),
#  ('912', 4),
#  ('911', 4),
#  ('581', 4),
#  ('975', 4),
#  ('289', 4),
#  ('799', 4),
#  ('967', 4),
#  ('970', 4),
#  ('507', 4),
#  ('917', 4),
#  ('146', 4),
#  ('081', 4),
#  ('387', 4),
#  ('299', 4),
#  ('883', 4),
#  ('725', 4),
#  ('838', 4),
#  ('296', 4),
#  ('266', 4),
#  ('921', 4),
#  ('708', 4),
#  ('800', 4),
#  ('420', 3),
#  ('812', 3),
#  ('919', 3),
#  ('760', 3),
#  ('427', 3),
#  ('737', 3),
#  ('609', 3),
#  ('234', 3),
#  ('880', 3),
#  ('232', 3),
#  ('270', 3),
#  ('494', 3),
#  ('711', 3),
#  ('986', 3),
#  ('630', 3),
#  ('974', 3),
#  ('408', 3),
#  ('391', 3),
#  ('575', 3),
#  ('590', 3),
#  ('220', 3),
#  ('597', 3),
#  ('385', 3),
#  ('945', 3),
#  ('978', 3),
#  ('388', 3),
#  ('900', 3),
#  ('660', 3),
#  ('400', 3),
#  ('949', 3),
#  ('109', 3),
#  ('629', 3),
#  ('573', 3),
#  ('197', 3),
#  ('994', 3),
#  ('411', 3),
#  ('380', 3),
#  ('350', 3),
#  ('326', 3),
#  ('108', 3),
#  ('649', 3),
#  ('495', 3),
#  ('784', 2),
#  ('502', 2),
#  ('651', 2),
#  ('025', 2),
#  ('842', 2),
#  ('368', 2),
#  ('925', 2),
#  ('643', 2),
#  ('513', 2),
#  ('567', 2),
#  ('936', 2),
#  ('185', 2),
#  ('154', 2),
#  ('204', 2),
#  ('635', 2),
#  ('414', 2),
#  ('415', 2),
#  ('031', 2),
#  ('618', 2),
#  ('182', 2),
#  ('562', 2),
#  ('639', 2),
#  ('854', 2),
#  ('425', 2),
#  ('560', 2),
#  ('580', 2),
#  ('664', 2),
#  ('454', 2),
#  ('927', 2),
#  ('079', 2),
#  ('981', 2),
#  ('965', 2),
#  ('579', 2),
#  ('946', 2),
#  ('541', 2),
#  ('977', 2),
#  ('404', 2),
#  ('939', 2),
#  ('540', 2),
#  ('578', 2),
#  ('870', 2),
#  ('979', 2),
#  ('926', 2),
#  ('732', 2),
#  ('409', 2),
#  ('293', 2),
#  ('396', 2),
#  ('292', 2),
#  ('376', 2),
#  ('758', 2),
#  ('161', 2),
#  ('383', 2),
#  ('272', 2),
#  ('868', 2),
#  ('757', 2),
#  ('779', 2),
#  ('830', 2),
#  ('826', 2),
#  ('123', 2),
#  ('080', 2),
#  ('547', 2),
#  ('360', 2),
#  ('935', 2),
#  ('215', 2),
#  ('231', 1),
#  ('871', 1),
#  ('932', 1),
#  ('622', 1),
#  ('601', 1),
#  ('136', 1),
#  ('348', 1),
#  ('430', 1),
#  ('723', 1),
#  ('529', 1),
#  ('417', 1),
#  ('284', 1),
#  ('373', 1),
#  ('026', 1),
#  ('786', 1),
#  ('707', 1),
#  ('829', 1),
#  ('367', 1),
#  ('669', 1),
#  ('620', 1),
#  ('663', 1),
#  ('195', 1),
#  ('349', 1),
#  ('353', 1),
#  ('627', 1),
#  ('071', 1),
#  ('559', 1),
#  ('273', 1),
#  ('681', 1),
#  ('897', 1),
#  ('802', 1),
#  ('407', 1),
#  ('647', 1),
#  ('652', 1),
#  ('033', 1),
#  ('198', 1),
#  ('553', 1),
#  ('964', 1),
#  ('386', 1),
#  ('827', 1),
#  ('262', 1),
#  ('536', 1),
#  ('239', 1),
#  ('140', 1),
#  ('834', 1),
#  ('156', 1),
#  ('794', 1),
#  ('582', 1),
#  ('632', 1),
#  ('966', 1),
#  ('532', 1),
#  ('122', 1),
#  ('807', 1),
#  ('860', 1),
#  ('357', 1),
#  ('831', 1),
#  ('274', 1),
#  ('874', 1),
#  ('881', 1),
#  ('852', 1),
#  ('888', 1),
#  ('468', 1),
#  ('032', 1),
#  ('971', 1),
#  ('722', 1),
#  ('985', 1),
#  ('533', 1),
#  ('755', 1),
#  ('554', 1),
#  ('724', 1),
#  ('702', 1),
#  ('705', 1),
#  ('235', 1),
#  ('624', 1),
#  ('157', 1),
#  ('990', 1),
#  ('177', 1),
#  ('899', 1),
#  ('991', 1),
#  ('439', 1),
#  ('366', 1),
#  ('226', 1),
#  ('787', 1),
#  ('600', 1),
#  ('163', 1),
#  ('890', 1),
#  ('343', 1),
#  ('929', 1),
#  ('176', 1),
#  ('295', 1),
#  ('492', 1),
#  ('015', 1),
#  ('096', 1),
#  ('805', 1),
#  ('478', 1),
#  ('488', 1),
#  ('803', 1),
#  ('254', 1),
#  ('738', 1),
#  ('542', 1),
#  ('196', 1),
#  ('918', 1),
#  ('188', 1),
#  ('199', 1),
#  ('221', 1),
#  ('634', 1),
#  ('413', 1),
#  ('028', 1),
#  ('162', 1),
#  ('116', 1),
#  ('873', 1),
#  ('135', 1),
#  ('728', 1),
#  ('712', 1),
#  ('840', 1),
#  ('280', 1),
#  ('896', 1),
#  ('862', 1),
#  ('101', 1),
#  ('120', 1),
#  ('113', 1),
#  ('114', 1),
#  ('503', 1),
#  ('617', 1),
#  ('203', 1),
#  ('640', 1),
#  ('872', 1),
#  ('646', 1),
#  ('841', 1),
#  ('908', 1),
#  ('002', 1),
#  ('633', 1),
#  ('569', 1),
#  ('374', 1),
#  ('543', 1),
#  ('739', 1),
#  ('271', 1),
#  ('183', 1),
#  ('922', 1),
#  ('747', 1),
#  ('550', 1),
#  ('104', 1)]

# %%
import pickle

with open("cat_to_ids.pkl", "wb") as f:
	pickle.dump(filtered_cat_to_ids, f)
